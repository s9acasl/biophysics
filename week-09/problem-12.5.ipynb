# %% [markdown]
# # 12.5 MY LITTLE RUNAWAY
#
# Use this notebook to store your work for this problem.

# %% [markdown]
# ## Initial Conditions
#
# Make at least 3 separate plots:
#
# - $x_0 < -1$
# - $-1 < x_0 < 1$
# - $x_0 > 1$
#
# After you have explored these regimes, comment on the behavior you observed.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-1.5,-1,10)
Wx1 = x**2 + 1
plt.plot(Wx1)
plt.title("x0 < 1")
# Out:
# Text(0.5, 1.0, 'x0 < 1')

# %%
x = np.linspace(-1,1,10)
Wx2 = x**2 + 1
plt.plot(Wx2)
plt.title("-1<x0<1")
# Out:
# Text(0.5, 1.0, '-1<x0<1')

# %%
x = np.linspace(1,10,10)
Wx3 = x**2 + 1
plt.plot(Wx3)
plt.title("x0>1")
# Out:
# Text(0.5, 1.0, 'x0>1')

# %%
x,y = np.meshgrid(np.linspace(-5,5,10),np.linspace(-5,5,10))
u = -x**2 + 1
v = -x**2 + 1

plt.quiver(x,y,u,v)
plt.plot(Wx1)
plt.plot(Wx2)
plt.plot(Wx3)
plt.xlim(-5,5)
plt.ylim(-5,5)
# Out:
# (-5.0, 5.0)

# %% [markdown]
# ***I understand what we're supposed to be seeing, the analogy with the chair and runaway systems makes a lot of sense.  I'm just lost on implementing these functions in Python.***

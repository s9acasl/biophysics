# %% [markdown]
# # 11.2 COOPERATIVE BINDING DATA
#
# Use this notebook to store your work for this problem.

# %% [markdown]
# ## (a) Fit by eye

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import leastsq
from scipy.optimize import least_squares
from scipy import optimize

# %%
hemo = np.load('hemoglobin.npy')
hemo1 = hemo[:,0]
hemo2 = hemo[:,1]
x = np.linspace(0,44,700)
fit = 1 / (1 + x**3)

# %%
plt.loglog(hemo2,'.',label = 'Data')
plt.loglog(fit, label = 'Fit Function, n = 3')
plt.ylim(0.025,1.5)
plt.legend()
_=plt.title("Fitting Hemoglobin Data")

# %% [markdown]
# ## (b) Least-squares fit

# %%
x = hemo2
y = 1 / (1 + x**3)

# %%
A = np.vstack([x, np.ones(len(x))]).T

y = y[:, np.newaxis]

alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T,A)),A.T)),y)
print(alpha)
# Out:
# [[-0.51255423]
#  [ 1.07097432]]

# %%
plt.figure(figsize = (10,8))
plt.plot(x, y, 'b.')
plt.plot(x, alpha[0]*x + alpha[1], 'r')
plt.plot(hemo2,'r.')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# **Definitely having some issues with the least squres fitting... Not really sure where to go with it.**

# %% [markdown]
# # 11.6 NUMERICAL SOLUTION OF PHASE-PORTRAIT EQUATIONS
#
# Use this notebook to store your work for this problem.

# %% [markdown]
# Plot at least 4 different solutions for initial values of $(\theta, \omega)$ on top of your streamline plot from Problem 11.5.
#
# Neatness counts!  Make the plot look as nice as you can.

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.integrate import odeint

# %%
def f(Y, t):
    y1, y2 = Y
    return [y2, -np.sin(y1)]

y1 = np.linspace(-2.0, 8.0, 20)
y2 = np.linspace(-2.0, 2.0, 20)

Y1, Y2 = np.meshgrid(y1, y2)

t = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape
#theta = np.linspace(-2,8,100)
#motion = 2 * np.cos(theta)
#plt.plot(theta,motion)
for i in range(NI):
    for j in range(NJ):
        x = Y1[i, j]
        y = Y2[i, j]
        yprime = f([x, y], t)
        u[i,j] = yprime[0]
        v[i,j] = yprime[1]
     

plt.quiver(Y1, Y2, u, v, color='r')
#plt.plot(theta,motion)
plt.xlabel('angular position')
plt.ylabel('Lw')
plt.xlim([-2, 4])
_=plt.ylim([-2, 2])

for y20 in [1/3, 1,1.5,2.0]:
    tspan = np.linspace(0, 50, 200)
    y0 = [0.0, y20]
    ys = odeint(f, y0, tspan)
    plt.plot(ys[:,0], ys[:,1], 'b-') # path
   # plt.plot([ys[0,0]], [ys[0,1]], 'o') # start
   # plt.plot([ys[-1,0]], [ys[-1,1]], 's') # end
    

plt.xlim([-2, 8])
# Out:
# (-2.0, 8.0)

# %% [markdown]
# *** Well, I'm not really sure what I'm doing with this, but I gave it my best try. ***
